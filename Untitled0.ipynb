# %% [markdown]
# <a href="https://colab.research.google.com/github/davidrivaszz/prograIII-semi-2026/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fahreheit_celcius = lambda f: (f-32) * 5/9

f = float(input("ingrese los grados fahrenheit:"))

print("grados celcius:", fahreheit_celcius(f))

# %%
celcius_kelvin = lambda c: c + 273.15

c = float(input("ingrese los grados celcius:"))

print("grados klevin:", celcius_kelvin(c))

# %%
sueldo = lambda h,v:h*v*30

horas = float(input("horas trabajadas por dia:"))

valor = float(input("valor por hora:$"))

bruto = sueldo(horas,valor)

isss = *0.03
afp = *0.0725
isr = 0 # canbiar segun la tabla del mh

neto = bruto-iss-afp-isr

print("sueldo:$",bruto)
print("isss:$",isss)
print("afp:$",afp)
print("isr:$",isr)
print("sueldo neto:$",neto)

# %%
potencia = lambda base,exponente:base**exponente

base = float(input("ingrese la base:"))

expo = float(input("ingrese el exponente:"))

print("resultado:",potencia(base, expo)))

# %%
persona = {
    "codigo": "usI501884",
    "nombre": "david rivas",
    "materias": [
        {
            "codigo": 611,
            "nombre": "progra I",
            "notas": {
                "c1": {"lab1": 8, "lab2": 7, "parcial": 9},
                "c2": {"lab1": 8, "lab2": 7, "parcial": 9},
                "c3": {"lab1": 8, "lab2": 7, "parcial": 9}
            }
        },
        {
            "codigo": 612,
            "nombre": "progra II",
            "notas": {
                "c1": {"lab1": 8, "lab2": 7, "parcial": 9},
                "c2": {"lab1": 8, "lab2": 7, "parcial": 9},
                "c3": {"lab1": 8, "lab2": 7, "parcial": 9}
            }
        }
    ]
}

# %%
print(persona["nombre"],"materias:", persona["materias"][0]["nombre"])
print(persona["materias"][0]["notas"]["c1"]["parcial"])
# Out:
# david rivas materias: progra I
# 9
