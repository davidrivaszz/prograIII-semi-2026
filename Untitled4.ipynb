# %% [markdown]
# <a href="https://colab.research.google.com/github/davidrivaszz/prograIII-semi-2026/blob/Parcial/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class estudiantes:
    def __init__(self,nombre,notas,materias,edad,t_pantalla,t_universidad):
        self.nombre = nombre
        self.notas = notas
        self.materias = materias
        self.t_pantalla = t_pantalla
        self.t_universidad = t_universidad
        self.edad = edad

#MEDIA ARITMETICA
def calcular_media_aritmetica(estudiantes):
    sum_notas = sum(estudiantes.notas)
    total_notas = len(estudiantes.notas)
    resultado = sum_notas/total_notas


    return resultado

#key compara frecuencias y la funcion max por si sla no puede hacerlo
#MODA
def calcular_moda(estudiantes):
    notas = estudiantes.notas
    val_unico = set(notas)
    moda = max(val_unico , key=notas.count)

    return moda

#VARIANZA
def calcular_varianza(estudiantes):
    cantidad_notas = len(estudiantes.notas)
    promedio = sum(estudiantes.notas) / cantidad_notas

    suma_cuadrado = 0
    for elemento in estudiantes.notas:
        resta = elemento - promedio
        suma_cuadrado += resta ** 2

    varianza = suma_cuadrado / cantidad_notas

    return varianza

#RANGO
def calcular_rango(estudiantes):
    rango = max(estudiantes.notas)-min(estudiantes.notas)

    return rango

#MEDIANA
def calcular_mediana(estudiantes):
    notas_ordenadas = sorted(estudiantes.notas)
    cantidad_notas = len(notas_ordenadas)
    mitad = cantidad_notas // 2

    if cantidad_notas % 2 == 0:
        mediana = (notas_ordenadas[mitad - 1] + notas_ordenadas[mitad]) / 2
    else:
        mediana = notas_ordenadas[mitad]

    return mediana

#FRECUENCIA
def calcular_frecuencia(estudiantes):
    notas = estudiantes.notas
    frecuencia = {}
    for nota in notas:
        if nota in frecuencia:
            frecuencia[nota] += 1
        else:
            frecuencia[nota] = 1

    return frecuencia


#aun me faltan cuatro funciones y agregar a 7 estudiantes UwU



#para guardar los datos de los estudiantes  UwU
list_estudiante = [estudiantes("Sharon Nicole Arguello Torres",[10,10,10,10],
                ["Circuitos Digitales","Estadistica computacional",
                 "Administracion de bases de datos III","Ingles Basico"],21,
                 3,1),
                 estudiantes("Rodrigo Benjamín Baires Flores",[10,10,10,10],
                    ["Circuitos Digitales","Estadistica computacional",
                     "Administracion de bases de datos III","Ingles Basico"],20,1.20,6),
                estudiantes("David Alberto Beltran Rivas",[9,9,10,10],
                     ["Circuitos Digitales","Estadistica computacional",
                        "Administracion de bases de datos III","Ingles Basico"],20,0.25,5),
                estudiantes("Anderson Martin Bonilla Argueta",[10,10,10,10],
                     ["Circuitos Digitales","Estadistica computacional",
                        "Administracion de bases de datos III","Ingles Basico"],19,0.30,5),
                estudiantes("Kevin Manrique Campos Granados",[10,10,10,10],
                     ["Circuitos Digitales","Estadistica computacional",
                         "Administracion de bases de datos III","Ingles Basico"],21,2,7),
                estudiantes("Flor Zulema Campos Orellana",[10,10,10,9],
                     ["Circuitos Digitales","Estadistica computacional",
                      "Administracion de bases de datos III","Ingles Basico"],20,0.45,3),
                estudiantes("Ricardo Jose Carcamo Jimenez",[10,10,10,9],
                       ["Circuitos Digitales","Estadistica computacional",
                        "Administracion de bases de datos III","Ingles Basico"],19,0.15,4,),
                estudiantes("Jefferson Steven Castillo Leiva",[10,10,10,9],
                            ["Circuitos Digitales","Estadistica computacional",
                             "Administracion de bases de datos III","Ingles Basico"],19,0.30,5),
                estudiantes("Kimberly Michelle Castro Zelaya",[10,10,10,9],
                            ["Circuitos Digitales","Estadistica computacional",
                             "Administracion de bases de datos III","Ingles Basico"],19,0.15,2),
                estudiantes("Oscar Steven Chicas Huezo",[10,10,10,9],
                            ["Circuitos Digitales","Estadistica computacional",
                             "Administracion de bases de datos III","Ingles Basico"],22,0.7,13),
                estudiantes("Holman Israel Cisneros Romero",[10,10,10,9],
                            ["Circuitos Digitales","Estadistica computacional",
                             "Administracion de bases de datos III","Ingles Basico"],25,0.10,5),
                estudiantes("Ramael Ernesto Cordova Colindres",[10,10,10,10],
                            ["Circuitos Digitales","Estadistica computacional",
                             "Administracion de bases de datos III","Ingles Basico"],19,0.30,9),
                estudiantes("Jose Roberto Diaz Diaz",[10,10,10,10],
                            ["Circuitos Digitales","Estadistica computacional",
                             "Administracion de bases de datos III","Ingles Basico"],20,1.30,8)]


print("<<<<Sistema Estadístico Académico>>>>>")

#utilizare esto en caso de crear el menu de operaciones
operacion = ['Media aritmetica',
#Mediana
'Moda',
'Varianza',
#Desviacion estandar,
#Desviacion tipica ,
'Rango',
#Frecuencia


]


for i, persona in enumerate(list_estudiante, start=1):
    print(f"--- Persona #{i} ---")
    print(f"Nombre:    {persona.nombre}")
    print(f"Edad:      {persona.edad}")
    print("-" * 20)
estudiante=int(input("Selecciona un estudiante: "))-1
est_seleccionado = list_estudiante[estudiante]






diccionario_de_valores = {
   "moda":calcular_moda(est_seleccionado),
    "media aritmetica":calcular_media_aritmetica(est_seleccionado),
    "mediana":calcular_mediana(est_seleccionado),
    "Varianza":calcular_varianza(est_seleccionado),
    "Rango":calcular_rango(est_seleccionado),
    "frecuencia":calcular_frecuencia(est_seleccionado)}


formato = ""
for resultados,valores in diccionario_de_valores.items():
    l =  f"• {resultados}: {valores} \n"
    formato  +=  l
    print(f"• {resultados}: {valores}")
# Out:
# <<<<Sistema Estadístico Académico>>>>>
# --- Persona #1 ---
# Nombre:    Sharon Nicole Arguello Torres
# Edad:      21
# --------------------
# --- Persona #2 ---
# Nombre:    Rodrigo Benjamín Baires Flores
# Edad:      20
# --------------------
# --- Persona #3 ---
# Nombre:    David Alberto Beltran Rivas
# Edad:      20
# --------------------
# --- Persona #4 ---
# Nombre:    Anderson Martin Bonilla Argueta
# Edad:      19
# --------------------
# --- Persona #5 ---
# Nombre:    Kevin Manrique Campos Granados
# Edad:      21
# --------------------
# --- Persona #6 ---
# Nombre:    Flor Zulema Campos Orellana
# Edad:      20
# --------------------
# --- Persona #7 ---
# Nombre:    Ricardo Jose Carcamo Jimenez
# Edad:      19
# --------------------
# --- Persona #8 ---
# Nombre:    Jefferson Steven Castillo Leiva
# Edad:      19
# --------------------
# --- Persona #9 ---
# Nombre:    Kimberly Michelle Castro Zelaya
# Edad:      19
# --------------------
# --- Persona #10 ---
# Nombre:    Oscar Steven Chicas Huezo
# Edad:      22
# --------------------
# --- Persona #11 ---
# Nombre:    Holman Israel Cisneros Romero
# Edad:      25
# --------------------
# --- Persona #12 ---
# Nombre:    Ramael Ernesto Cordova Colindres
# Edad:      19
# --------------------
# --- Persona #13 ---
# Nombre:    Jose Roberto Diaz Diaz
# Edad:      20
# --------------------
# Selecciona un estudiante: 13
# • moda: 10
# • media aritmetica: 10.0
# • mediana: 10.0
# • Varianza: 0.0
# • Rango: 0
# • frecuencia: {10: 4}

# %%
# CALCULO DEL IMPUESTO

tabla = [
    (0.01,      500.00,      1.5,  0),
    (500.01,    1000.00,     1.5,  3),
    (1000.01,   2000.00,     3,    3),
    (2000.01,   3000.00,     6,    3),
    (3000.01,   6000.00,     9,    2),
    (8000.01,   18000.00,    15,   2),
    (18000.01,  30000.00,    39,   2),
    (30000.01,  60000.00,    63,   1),
    (60000.01,  100000.00,   93,   0.8),
    (100000.01, 200000.00,   125,  0.7),
    (200000.01, 300000.00,   195,  0.6),
    (300000.01, 400000.00,   255,  0.45),
    (400000.01, 500000.00,   300,  0.4),
    (500000.01, 1000000.00,  340,  0.30),
    (1000000.01, 99999999.00, 490, 0.18),
]

# 1. Pedimos el monto al usuario
monto = float(input("Ingrese el monto de su actividad economica: $"))

# 2. Recorremos la tabla buscando el rango donde cae el monto
for desde, hasta, precio, adicional in tabla:
    if monto >= desde and monto <= hasta:


        resultado = monto - desde
        impuesto = resultado / 1000 * adicional + precio

        print("El impuesto a pagar es: $" + str(round(impuesto, 2)))
        break
# Out:
# Ingrese el monto de su actividad economica: $1875.79
# El impuesto a pagar es: $5.63

# %%
# CONVERSOR DE AREA - EL SALVADOR


# Diccionario: cuantos metros cuadrados equivale UNA unidad de cada tipo
unidades = {
    "a": ("Pie cuadrado",   0.092903),
    "b": ("Vara cuadrada",  0.698896),
    "c": ("Yarda cuadrada", 0.836127),
    "d": ("Metro cuadrado", 1),
    "e": ("Tarea",          698.896),
    "f": ("Manzana",        6988.96),
    "g": ("Hectarea",       10000),
}


def convertir(valor, origen, destino):
    # 1. paso el valor a metros cuadrados
    metros = valor * unidades[origen][1]
    # 2. de metros cuadrados lo paso a la unidad destino
    return metros / unidades[destino][1]


# --- Programa principal ---
print("a) Pie cuadrado   b) Vara cuadrada   c) Yarda cuadrada")
print("d) Metro cuadrado e) Tarea           f) Manzana   g) Hectarea")

origen = input("Unidad que tiene: ")
destino = input("Unidad a la que quiere convertir: ")
valor = float(input("Valor a convertir: "))

resultado = convertir(valor, origen, destino)

print(f"{valor} {unidades[origen][0]} = {round(resultado, 4)} {unidades[destino][0]}")
# Out:
# a) Pie cuadrado   b) Vara cuadrada   c) Yarda cuadrada
# d) Metro cuadrado e) Tarea           f) Manzana   g) Hectarea
# Unidad que tiene: b
# Unidad a la que quiere convertir: a
# Valor a convertir: 1
# 1.0 Vara cuadrada = 7.5229 Pie cuadrado
